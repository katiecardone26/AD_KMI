# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reference Metadata

# %%
meta = pd.read_csv('/home/vrasik35/group/personal/rasika/ROSMAP_TWAS/Metadata/ROSMAP_biospecimen_metadata.csv', sep = ',')
meta[['individualID', 'specimenID']]
# Out:
#       individualID        specimenID
# 0         R1571846  Microglia_MO_AD1
# 1         R9188267  Microglia_MO_AD2
# 2         R3728445  Microglia_MO_AD3
# 3         R1246326  Microglia_MO_AD4
# 4         R9443041  Microglia_MO_AD5
# ...            ...               ...
# 12272     R2757104        DUKE-08135
# 12273     R9354381        DUKE-08136
# 12274     R2711188        DUKE-08137
# 12275     R9047934        DUKE-08138
# 12276     R2385937        DUKE-08139
#
# [12277 rows x 2 columns]

# %% [markdown]
# ## Genomic Data

# %%
array_data = pd.read_csv('Genomics/ROSMAP_arrayGenotype_geno0.01_maf0.01_hwe-8_prunedextract.fam', sep = '\t', header = None)
array_data[['Study', 'projid']] = array_data[1].str.split(r'ROS|MAP', expand = True)
array_data['projid'] = array_data['projid'].astype(int)
array_data['Study'] = array_data[1].str[:3]
array_data
# Out:
#                                          0            1  2  3  4  5 Study  \
# 0     KronosII_P01_6.0_A01_ROS20275399.CEL  ROS20275399  0  0  2 -9   ROS
# 1     KronosII_P01_6.0_A02_ROS10442701.CEL  ROS10442701  0  0  1 -9   ROS
# 2     KronosII_P01_6.0_A03_ROS20152393.CEL  ROS20152393  0  0  2 -9   ROS
# 3     KronosII_P01_6.0_A04_ROS20626558.CEL  ROS20626558  0  0  2 -9   ROS
# 4     KronosII_P01_6.0_A05_ROS15176592.CEL  ROS15176592  0  0  1 -9   ROS
# ...                                    ...          ... .. .. .. ..   ...
# 1703                               PT-BY8W  MAP50408491  0  0  2 -9   MAP
# 1704                               PT-BY87  MAP42063693  0  0  2 -9   MAP
# 1705                               PT-BYK9  MAP50405330  0  0  1 -9   MAP
# 1706                               PT-C13X  ROS20254452  0  0  2 -9   ROS
# 1707                               PT-C1EG  ROS20701008  0  0  2 -9   ROS
#
#         projid
# 0     20275399
# 1     10442701
# 2     20152393
# 3     20626558
# 4     15176592
# ...        ...
# 1703  50408491
# 1704  42063693
# 1705  50405330
# 1706  20254452
# 1707  20701008
#
# [1708 rows x 8 columns]

# %%
array_data[1]
# Out:
# 0       ROS20275399
# 1       ROS10442701
# 2       ROS20152393
# 3       ROS20626558
# 4       ROS15176592
#            ...
# 1703    MAP50408491
# 1704    MAP42063693
# 1705    MAP50405330
# 1706    ROS20254452
# 1707    ROS20701008
# Name: 1, Length: 1708, dtype: object

# %%
biomap = array_data.merge(meta[['individualID', 'specimenID']], left_on = 0, right_on = 'specimenID')
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4, 5, Study, projid, individualID, specimenID]
# Index: []

# %%
clinmeta = pd.read_csv('/home/vrasik35/group/datasets/rosmap/Metadata/ROSMAP_clinical.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-613f63cf8b6a> in <module>
#       1 clinmeta = pd.read_csv('/home/vrasik35/group/datasets/rosmap/Metadata/ROSMAP_clinical.csv')
# ----> 2 array_data.merge(clinmeta)
#
# /misc/appl/python-3.8/lib/python3.8/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9841         from pandas.core.reshape.merge import merge
#    9842
# -> 9843         return merge(
#    9844             self,
#    9845             right,
#
# /misc/appl/python-3.8/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#
# /misc/appl/python-3.8/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     739         # validate the merge keys dtypes. We may need to coerce
#     740         # to avoid incompatible dtypes
# --> 741         self._maybe_coerce_merge_keys()
#     742
#     743         # If argument passed to validate,
#
# /misc/appl/python-3.8/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _maybe_coerce_merge_keys(self)
#    1399                     inferred_right in string_types and inferred_left not in string_types
#    1400                 ):
# -> 1401                     raise ValueError(msg)
#    1402
#    1403             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %%
mappings = array_data.merge(clinmeta, how = 'outer').dropna(subset = 1)[[1, 'individualID']]
mappings.rename(columns = {1:'specimenID'}, inplace = True)
mappings.to_csv('Genomics/specimentoindiv_mapping.csv', index = False)

# %%
array_data.merge(mappings, left_on = 1, right_on = 'specimenID')[[0, 'individualID', 2,3,4,5]].dropna().to_csv('Genomics/individualID_mapped/ROSMAP_arrayGenotype_indiv.fam', sep = '\t', 
                                                                                                      header = None, index = None)

# %% [markdown]
# ## Transcriptomic Data

# %%
rnaseq = pd.read_csv('/home/vrasik35/group/personal/rasika/ROSMAP_TWAS/RNAseq/ROSMAP_RNAseq_FPKM_individualids.tsv', sep = '\t')
rnaseq = rnaseq.dropna().set_index('individualID')

# %%
# Function to convert FPKM to TPM
def fpkm_to_tpm(fpkm):
    return np.exp(np.log(fpkm) - np.log(np.sum(fpkm)) + np.log(1e6))

rnaseq_tpm = rnaseq.astype('float').apply(fpkm_to_tpm)
rnaseq_tpm
# Out:
# /misc/appl/python-3.8/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-46-bb6882293758>:3: RuntimeWarning: divide by zero encountered in log
#   return np.exp(np.log(fpkm) - np.log(np.sum(fpkm)) + np.log(1e6))
#               ENSG00000167578  ENSG00000242268  ENSG00000078237  \
# individualID
# R9976232          1886.964096       1174.10265      1882.974810
# R9936070          1192.970950       1509.56055      1103.645904
# R9907075          2014.159857       1174.10265      1137.529769
# R9905342          1573.468762       3522.30795      1941.061436
# R9904978          1706.928982       4528.68165       929.386024
# ...                       ...              ...              ...
# R1360065          1343.045606       1174.10265      1950.742541
# R1327471           843.250699       1341.83160      2420.276105
# R1224782          1011.573997          0.00000      2420.276105
# R1133959          1389.620499          0.00000      2497.724940
# R1067972          1285.031265          0.00000      2652.622611
#
#               ENSG00000263642  ENSG00000225275  ENSG00000060642  \
# individualID
# R9976232                  NaN              NaN      2206.525893
# R9936070                  NaN              NaN      1397.055500
# R9907075                  NaN              NaN      1376.510566
# R9905342                  NaN              NaN      1844.935057
# R9904978                  NaN              NaN      1253.240963
# ...                       ...              ...              ...
# R1360065                  NaN              NaN      2424.302191
# R1327471                  NaN              NaN      2128.455144
# R1224782                  NaN              NaN      1733.992415
# R1133959                  NaN              NaN      1988.749594
# R1067972                  NaN              NaN      2243.506774
#
#               ENSG00000201788  ENSG00000263089  ENSG00000172137  \
# individualID
# R9976232                  NaN              0.0       904.418827
# R9936070                  NaN              0.0       956.519764
# R9907075                  NaN              0.0      2655.811860
# R9905342                  NaN              0.0      1902.352157
# R9904978                  NaN              0.0      2646.460409
# ...                       ...              ...              ...
# R1360065                  NaN              0.0       651.929672
# R1327471                  NaN              0.0      1612.457200
# R1224782                  NaN              0.0      3610.995702
# R1133959                  NaN              0.0       932.473178
# R1067972                  NaN              0.0      1180.954569
#
#               ENSG00000240423  ...  ENSG00000232668  ENSG00000089177  \
# individualID                   ...
# R9976232           523.491690  ...              0.0      1896.589339
# R9936070          1308.729224  ...              0.0      1073.376482
# R9907075          1439.602146  ...              0.0      1687.150025
# R9905342          1439.602146  ...              0.0      1751.145371
# R9904978          2486.585525  ...              0.0      2548.178314
# ...                       ...  ...              ...              ...
# R1360065           916.110457  ...              0.0       954.112428
# R1327471          1046.983379  ...              0.0      2106.028652
# R1224782             0.000000  ...              0.0      1986.764599
# R1133959          1308.729224  ...              0.0      1890.771580
# R1067972           392.618767  ...              0.0       893.025962
#
#               ENSG00000216352  ENSG00000267117  ENSG00000148943  \
# individualID
# R9976232                  NaN              0.0      1792.860063
# R9936070                  NaN              0.0      1362.786030
# R9907075                  NaN              0.0      1281.372839
# R9905342                  NaN              0.0      1555.699897
# R9904978                  NaN              0.0      1387.563958
# ...                       ...              ...              ...
# R1360065                  NaN              0.0      1530.921969
# R1327471                  NaN              0.0      3065.383642
# R1224782                  NaN              0.0      2090.195197
# R1133959                  NaN              0.0      2637.079461
# R1067972                  NaN              0.0      1714.986576
#
#               ENSG00000265520  ENSG00000231119  ENSG00000105063  \
# individualID
# R9976232                  NaN      2852.162890      1720.592672
# R9936070                  NaN      1901.441927      1058.111030
# R9907075                  NaN      1426.081445      2028.820973
# R9905342                  NaN      3010.616384      1245.465487
# R9904978                  NaN      1980.668674      1592.280438
# ...                       ...              ...              ...
# R1360065                  NaN      1584.534939       858.669188
# R1327471                  NaN      1346.854698      1793.116978
# R1224782                  NaN      1188.401204      1100.881775
# R1133959                  NaN      2218.348915      1033.936261
# R1067972                  NaN      1584.534939       957.692760
#
#               ENSG00000123685  ENSG00000181518
# individualID
# R9976232          1889.586318              0.0
# R9936070          1367.373372              0.0
# R9907075          1216.206467              0.0
# R9905342          1779.646750              0.0
# R9904978          2820.637031              0.0
# ...                       ...              ...
# R1360065           803.933088              0.0
# R1327471          1257.433804              0.0
# R1224782          1460.134882              0.0
# R1133959           924.179490              0.0
# R1067972          1315.839200              0.0
#
# [637 rows x 55889 columns]

# %%
coding_list = set(pd.read_csv('/home/vrasik35/group/personal/rasika/ROSMAP_TWAS/human_protein_coding.txt', sep= '\t')['Gene stable ID'])
keep_coding = list(coding_list.intersection(rnaseq_tpm.columns))

# of the 22.5k coding genes, there are 18952 coding genes quantified in ROSMAP RNAseq
rnaseq_tpm_coding = rnaseq_tpm[keep_coding]

# %%
rnaseq_tpm_coding.to_csv('Transcriptomics/ROSMAP_RNAseq_FPKM_individualids_codinggenes.tsv', sep = '\t')

# %%
## Filter genes w/ minimal expression: 5 TPM
gene_filt = []
for gene in rnaseq_tpm_coding.columns:
    if (rnaseq_tpm_coding[gene].median() > 5):
        gene_filt.append(gene)
rnaseq_tpm_coding_tpm5 = rnaseq_tpm_coding[gene_filt]

## log2 transform - first replace any values below 1 to 1
rnaseq_tpm_coding_tpm5_log2 = rnaseq_tpm_coding_tpm5.apply(lambda x: np.where(x < 1, 1.00, x))
rnaseq_tpm_coding_tpm5_log2 = np.log2(rnaseq_tpm_coding_tpm5_log2.astype('float'))
# rnaseq_gene_tpm_log2

## Normalize by mean of log transformed
# # merged_gene_exp_norm = (merged_gene_exp_filt-merged_gene_exp_filt.mean())/merged_gene_exp_filt.std()
# # merged_gene_exp_norm_df = pd.DataFrame(merged_gene_exp_norm, columns=merged_gene_exp.columns)
# # merged_gene_exp_norm = StandardScaler().fit_transform(merged_gene_exp_filt)  
# # merged_gene_exp_norm_df = pd.DataFrame(merged_gene_exp_norm, columns=merged_gene_exp_filt.columns)
# # merged_gene_exp_norm_df

rnaseq_gene_exp_norm_dict = {}
for i, j in rnaseq_tpm_coding_tpm5_log2.items():
    rnaseq_gene_exp_norm_dict[i] = j/rnaseq_tpm_coding_tpm5_log2[i].mean()
    
rnaseq_gene_exp_norm = pd.DataFrame.from_dict(rnaseq_gene_exp_norm_dict)
rnaseq_gene_exp_norm
# Out:
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /misc/appl/python-3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
#               ENSG00000204272  ENSG00000112852  ENSG00000102678  \
# individualID
# R9976232             1.047697         1.040724         1.071657
# R9936070             0.972089         1.045903         0.972021
# R9907075             1.019208         1.047587         1.029024
# R9905342             1.032022         0.979919         1.011148
# R9904978             1.007231         0.901482         0.999027
# ...                       ...              ...              ...
# R1360065             1.045191         0.915160         0.985285
# R1327471             1.012148         0.942646         0.979756
# R1224782             1.024036         1.029749         1.051705
# R1133959             1.041993         1.004797         1.080757
# R1067972             1.086643         0.891553         1.079396
#
#               ENSG00000112531  ENSG00000185386  ENSG00000164128  \
# individualID
# R9976232             1.020772         0.979168         1.044808
# R9936070             1.006092         0.962130         0.974430
# R9907075             0.927839         1.038134         1.000642
# R9905342             1.037932         0.957708         0.975628
# R9904978             0.893218         1.028558         1.010864
# ...                       ...              ...              ...
# R1360065             1.133737         1.017960         1.030889
# R1327471             1.054786         0.975904         1.106007
# R1224782             1.003681         0.983624         1.073402
# R1133959             1.041866         0.948135         1.097568
# R1067972             1.055069         1.072395         1.079898
#
#               ENSG00000165457  ENSG00000100060  ENSG00000139163  \
# individualID
# R9976232             1.086860         1.135251         1.092700
# R9936070             0.907814         0.947872         0.989352
# R9907075             1.004631         0.984556         0.933884
# R9905342             1.120568         1.044768         1.002193
# R9904978             0.809837         0.961546         0.991134
# ...                       ...              ...              ...
# R1360065             1.084925         1.046944         1.005425
# R1327471             0.899490         0.869701         0.988452
# R1224782             0.912357         0.960541         1.000548
# R1133959             0.850020         0.809716         1.034189
# R1067972             0.775728         0.896190         1.093550
#
#               ENSG00000183718  ...  ENSG00000205838  ENSG00000141027  \
# individualID                   ...
# R9976232             1.042382  ...         0.955895         0.986228
# R9936070             0.965295  ...         0.802631         0.987134
# R9907075             1.006428  ...         0.949088         1.033208
# R9905342             1.036552  ...         1.062219         0.977527
# R9904978             0.971413  ...         0.917958         1.040732
# ...                       ...  ...              ...              ...
# R1360065             1.010088  ...         1.119813         0.879188
# R1327471             1.063296  ...         0.980218         1.068093
# R1224782             1.043330  ...         0.990955         1.044262
# R1133959             1.046597  ...         1.090214         1.046700
# R1067972             0.987575  ...         1.115649         0.926225
#
#               ENSG00000172568  ENSG00000170837  ENSG00000069345  \
# individualID
# R9976232             1.110088         1.020366         1.031209
# R9936070             0.882113         0.943877         0.935575
# R9907075             0.991970         1.010588         0.996236
# R9905342             1.023559         0.972760         1.005094
# R9904978             1.010391         0.979799         0.941828
# ...                       ...              ...              ...
# R1360065             0.987073         1.046874         1.011966
# R1327471             1.046381         1.082800         1.086636
# R1224782             1.149087         1.063547         1.082744
# R1133959             1.055008         1.092921         1.103465
# R1067972             1.075227         1.118624         1.092638
#
#               ENSG00000044459  ENSG00000187323  ENSG00000114127  \
# individualID
# R9976232             1.041792         1.008793         1.030783
# R9936070             1.005036         0.842237         0.946073
# R9907075             1.020128         0.995497         0.967888
# R9905342             1.034640         0.938933         1.010815
# R9904978             1.018071         1.140784         0.960109
# ...                       ...              ...              ...
# R1360065             0.954618         0.938933         1.061133
# R1327471             1.056637         0.952229         1.045373
# R1224782             1.013863         1.052061         1.055931
# R1133959             1.048589         1.082569         1.023702
# R1067972             0.952960         0.952229         1.070185
#
#               ENSG00000164600  ENSG00000237489
# individualID
# R9976232             0.937878         0.948803
# R9936070             0.866274         0.948803
# R9907075             1.023185         1.051918
# R9905342             0.848973         0.940471
# R9904978             0.944659         1.046069
# ...                       ...              ...
# R1360065             0.984713         0.940471
# R1327471             1.105024         0.900935
# R1224782             1.107277         0.931602
# R1133959             1.095128         1.022202
# R1067972             1.152268         0.922120
#
# [637 rows x 16263 columns]

# %%
rnaseq_gene_exp_norm.to_csv('Transcriptomics/ROSMAP_RNAseq_TPM5_log2norm_individualids_codinggenes.tsv', sep = '\t')

# %% [markdown]
# ## Methylomics Data

# %%
methylation = pd.read_csv('~/gMethylomics/ROSMAP_arrayMethylation_imputed.tsv.gz', sep = '\t')
methyl_meta = pd.read_csv('Methylomics/ROSMAP_arrayMethylation_metaData.tsv', sep = '\t')

# %%
keep_transcripts = list(methyl_meta.dropna(subset = 'RefGene')['TargetID'])
methylation_refgene = methylation[methylation['TargetID'].isin(keep_transcripts)].T
methylation_refgene.columns = [methylation_refgene.iloc[0]]
methylation_refgene = methylation_refgene[1:]

# %%
colnames = methylation_refgene.columns

# %%
methylation_refgene_individualid = methylation_refgene.merge(meta[['individualID', 'specimenID']], left_index=True, right_on = 'specimenID').set_index('individualID').drop(columns = ['specimenID'])
methylation_refgene_individualid.columns = colnames

# %%
methylation_refgene_individualid
# Out:
# TargetID     cg00000957 cg00001349 cg00001364 cg00001446 cg00001534  \
# individualID
# R3978789        0.77622   0.865488   0.772899   0.842025    0.88392
# R8140052       0.818279    0.91957   0.711099   0.831457   0.877727
# R7881801       0.630316   0.882256   0.694639   0.835075   0.843842
# R6108690       0.849261   0.902912   0.651986   0.834157   0.917063
# R9662437       0.861136    0.90761   0.748538   0.839395   0.863272
# ...                 ...        ...        ...        ...        ...
# R6016948       0.692638   0.904996   0.733207   0.852642   0.898319
# R5259690       0.785597   0.927201   0.750224   0.833056   0.855475
# R1977848       0.712386   0.856637   0.737402   0.842108   0.895146
# R6536689       0.839168   0.917827   0.685959   0.841747   0.850789
# R6759986       0.888304    0.94332   0.770543   0.833336   0.923327
#
# TargetID     cg00001583 cg00002028 cg00002593 cg00002646 cg00002719  ...  \
# individualID                                                         ...
# R3978789       0.099888   0.026821   0.736051   0.889046   0.002725  ...
# R8140052        0.07624   0.035839   0.728072   0.888627   0.011835  ...
# R7881801       0.075861   0.020016   0.674905    0.84912   0.008358  ...
# R6108690       0.101837   0.014101   0.698835   0.877378        0.0  ...
# R9662437       0.071947    0.03139   0.764737   0.908272        0.0  ...
# ...                 ...        ...        ...        ...        ...  ...
# R6016948       0.059607   0.019535   0.742575   0.887808   0.000781  ...
# R5259690       0.116837   0.011352   0.720815   0.897804    0.00103  ...
# R1977848       0.069391   0.020888   0.696251   0.878899        0.0  ...
# R6536689       0.061016   0.035047   0.738012   0.916524   0.009139  ...
# R6759986       0.035535   0.026995   0.775927   0.944989   0.013819  ...
#
# TargetID     ch.22.78028F ch.22.163059F ch.22.427671F ch.22.439136F  \
# individualID
# R3978789         0.085649      0.187368      0.120821      0.066196
# R8140052         0.092679      0.125934      0.107421      0.074446
# R7881801         0.059054      0.164964      0.096951      0.083344
# R6108690         0.093534      0.095124      0.115163      0.051879
# R9662437          0.07029      0.099851      0.110676      0.046465
# ...                   ...           ...           ...           ...
# R6016948         0.099152      0.067795      0.100549      0.092159
# R5259690         0.090359      0.141899      0.108123      0.064988
# R1977848         0.072494      0.112585      0.129393       0.07438
# R6536689          0.09315      0.205678       0.09869      0.047593
# R6759986         0.097759      0.120184      0.083545      0.058276
#
# TargetID     ch.22.441164F ch.22.533187F ch.22.740407F ch.22.757911F  \
# individualID
# R3978789          0.083472      0.128748      0.139123      0.089335
# R8140052          0.069204       0.12509       0.12784      0.089504
# R7881801          0.147787       0.09544       0.11876      0.059411
# R6108690          0.018833      0.119385      0.091408      0.074204
# R9662437          0.120507      0.120238      0.108485       0.06273
# ...                    ...           ...           ...           ...
# R6016948          0.151308      0.123356      0.134127      0.057825
# R5259690          0.158463      0.113744      0.116528      0.049111
# R1977848          0.081349      0.144721      0.125282       0.08227
# R6536689          0.001287      0.088929      0.104598      0.101021
# R6759986          0.130476      0.128494      0.095087      0.061569
#
# TargetID     ch.22.772318F ch.22.909671F
# individualID
# R3978789          0.233366      0.409177
# R8140052           0.19837      0.463476
# R7881801          0.176775      0.307656
# R6108690          0.141996      0.302488
# R9662437           0.16761      0.426867
# ...                    ...           ...
# R6016948          0.193311      0.472419
# R5259690          0.149942      0.340013
# R1977848          0.135414      0.436682
# R6536689          0.123727      0.413712
# R6759986          0.121499      0.447053
#
# [740 rows x 323276 columns]

# %%
methylation_refgene_individualid.to_csv('Methylomics/Methylation_refgene_individualid.tsv', sep = '\t')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-1b3f680c91a6> in <module>
# ----> 1 methylation_refgene_individualid.to_csv('Methylomics/Methylation_refgene_individualid.tsv', sep = '\t')
#
# /misc/appl/python-3.8/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3770         )
#    3771
# -> 3772         return DataFrameRenderer(formatter).to_csv(
#    3773             path_or_buf,
#    3774             lineterminator=lineterminator,
#
# /misc/appl/python-3.8/lib/python3.8/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1184             formatter=self.fmt,
#    1185         )
# -> 1186         csv_formatter.save()
#    1187
#    1188         if created_buffer:
#
# /misc/appl/python-3.8/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     257             )
#     258
# --> 259             self._save()
#     260
#     261     def _save(self) -> None:
#
# /misc/appl/python-3.8/lib/python3.8/site-packages/pandas/io/formats/csvs.py in _save(self)
#     262         if self._need_to_save_header:
#     263             self._save_header()
# --> 264         self._save_body()
#     265
#     266     def _save_header(self) -> None:
#
# /misc/appl/python-3.8/lib/python3.8/site-packages/pandas/io/formats/csvs.py in _save_body(self)
#     300             if start_i >= end_i:
#     301                 break
# --> 302             self._save_chunk(start_i, end_i)
#     303
#     304     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# /misc/appl/python-3.8/lib/python3.8/site-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     307         df = self.obj.iloc[slicer]
#     308
# --> 309         res = df._mgr.to_native_types(**self._number_format)
#     310         data = [res.iget_values(i) for i in range(len(res.items))]
#     311
#
# /misc/appl/python-3.8/lib/python3.8/site-packages/pandas/core/internals/managers.py in to_native_types(self, **kwargs)
#     510         in formatting (repr / csv).
#     511         """
# --> 512         return self.apply("to_native_types", **kwargs)
#     513
#     514     @property
#
# /misc/appl/python-3.8/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     350                 applied = b.apply(f, **kwargs)
#     351             else:
# --> 352                 applied = getattr(b, f)(**kwargs)
#     353             result_blocks = extend_blocks(applied, result_blocks)
#     354
#
# /misc/appl/python-3.8/lib/python3.8/site-packages/pandas/core/internals/blocks.py in to_native_types(self, na_rep, quoting, **kwargs)
#     529     def to_native_types(self, na_rep: str = "nan", quoting=None, **kwargs) -> Block:
#     530         """convert to our native types format"""
# --> 531         result = to_native_types(self.values, na_rep=na_rep, quoting=quoting, **kwargs)
#     532         return self.make_block(result)
#     533
#
# /misc/appl/python-3.8/lib/python3.8/site-packages/pandas/core/internals/blocks.py in to_native_types(values, na_rep, quoting, float_format, decimal, **kwargs)
#    2575                 values = values.astype(f"<U{itemsize}")
#    2576         else:
# -> 2577             values = np.array(values, dtype="object")
#    2578
#    2579         values[mask] = na_rep
#
# KeyboardInterrupt:

# %%
methylation_individualid = methylation.merge(meta[['individualID', 'specimenID']], left_index=True, right_on = 'specimenID').set_index('individualID').drop(columns = ['specimenID'])
methylation_individualid.columns = colnames
methylation_individualid.to_csv('Methylomics/Methylation_alltranscripts_individualid.tsv', sep = '\t')

# %%
pd.read_csv('Methylomics/ROSMAP_arrayMethylation_imputed.tsv.gz', sep = '\t')
